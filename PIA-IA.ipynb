# %% [markdown]
# <a href="https://colab.research.google.com/github/2007856reyli/Actividades/blob/main/PIA-IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

X = np.array([
    [0.9,0.2,0.1],
    [0.8,0.3,0.1],
    [0.2,0.9,0.9],
    [0.3,0.8,0.8]
])

y = np.array([1,1,0,0])

model = Sequential()

model.add(Dense(1,input_dim=3,activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy'
)

model.fit(X,y,epochs=1000,verbose=0)

weights,bias = model.layers[0].get_weights()

print(weights)
print(bias)
# Out:
# [[ 1.017005  ]
#  [-0.21332395]
#  [-2.085179  ]]
# [0.5293635]
